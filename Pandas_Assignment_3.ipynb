# %% [markdown]
# ###  Import the necessary libraries

# %%
https://drive.google.com/file/d/1igc7RVv64J6fHKWOgtaMvNG2TO4GTOg_/view?usp=sharing

# %%
import pandas as pd

# %% [markdown]
# ### Load and assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

hotel = pd.read_csv(url, sep = '\t')

# %%
hotel.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ###  Sort  the dataframe chipo by item_name column

# %%
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %% [markdown]
# ### How many customers ordered  Veggie Salad Bowl item?

# %%
# Out:
# 18

# %% [markdown]
# ### How many times did someone order more than one Canned Soda?

# %%
# Out:
# 20

# %% [markdown]
# ### New Dataset

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep=',')
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
euro12.shape
# Out:
# (16, 35)

# %% [markdown]
# ### Set Team columns as index in euro dataframe

# %%
hotel[hotel["item_name"]=="Veggie Salad Bowl"].shape[0]
# Out:
# 18

# %% [markdown]
# ### Filter teams that scored more than 6 goals

# %%
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# ### Filter ['Denmark','Germany','Italy'] teams and ['Goals','Blocks'] columns from euro dataframe

# %%
# Out:
#          Goals  Blocks
# Team
# Denmark      4      10
# Germany     10      11
# Italy        6      18

# %% [markdown]
# ### Present only the Shooting Accuracy from England, Italy and Russia

# %%
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %% [markdown]
# ###  Select every row up to the 5th row and all columns

# %%
# Out:
#                 Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# Croatia             4               13                12             51.9%
# Czech Republic      4               13                18             41.9%
# Denmark             4               10                10             50.0%
# England             5               11                18             50.0%
# France              3               22                24             37.9%
#
#                % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# Croatia                   16.0%                          32             0
# Czech Republic            12.9%                          39             0
# Denmark                   20.0%                          27             1
# England                   17.2%                          40             0
# France                     6.5%                          65             1
#
# ...

# %% [markdown]
# ###  Select all rows and columns from 0 to 7

# %%
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...
